# %% [markdown]
# <a href="https://colab.research.google.com/github/adsakash1226/Data-Noida-2020-Jan/blob/master/convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img  = Image.open("../monestry.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x7F72BDE45048>

# %%
small = img.resize(size =(400,300))

# %%
small
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F72BC524CF8>

# %%
img  = np.array(small).mean(axis=2)

# %%
plt.imshow(img)

# %%
padded_img = np.pad(img,pad_width=1)

# %%
padded_img.shape
# Out:
# (302, 402)

# %%
plt.imshow(padded_img)

# %%
fil = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])

result = np.zeros_like(img)

for row in range(result.shape[0]):
    for col in range(result.shape[1]):
        cut = padded_img[row:row+3, col:col+3]
        result[row, col] = abs((cut * fil).mean())

plt.imshow(result, cmap="gray")

# %%
fil = np.array([[1, 0, -1], [1, 0, -1], [1, 0, -1]])

result = np.zeros_like(img)

for row in range(result.shape[0]):
    for col in range(result.shape[1]):
        cut = padded_img[row:row+3, col:col+3]
        result[row, col] = abs((cut * fil).mean())

plt.imshow(result, cmap="gray")
